# %% [markdown]
# ### 데이터 추출하는 법

# %%
import pandas as pd

# %%
mpg=pd.read_csv('mpg.csv')

# %%
mpg[['model','year']]
# Out:
#       model  year
# 0        a4  1999
# 1        a4  1999
# 2        a4  2008
# 3        a4  2008
# 4        a4  1999
# ..      ...   ...
# 229  passat  2008
# 230  passat  2008
# 231  passat  1999
# 232  passat  1999
# 233  passat  2008
#
# [234 rows x 2 columns]

# %% [markdown]
# ### 행 단위 데이터 추출시 꼭 알아야 하는 내용
# - loc : 인덱스를 기준으로 행 데이터 추출
# - iloc  : 행 번호를 기준으로 헹 데이터를 추출

# %%
df = pd.read_csv('gapminder.tsv',sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[1703]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.loc[233]
# Out:
# manufacturer    volkswagen
# model               passat
# displ                  3.6
# year                  2008
# cyl                      6
# trans             auto(s6)
# drv                      f
# cty                     17
# hwy                     26
# fl                       p
# category           midsize
# Name: 233, dtype: object

# %% [markdown]
# ### loc 이용해서 인덱스 기준 데이터를 추출할 때 변수를 입력해서도 가능하다!

# %%
number_of_rows =mpg.shape[0]

# %%
number_of_index = number_of_rows -12

# %%
number_of_index
# Out:
# 222

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.loc[number_of_index]
# Out:
# manufacturer    volkswagen
# model           new beetle
# displ                  1.9
# year                  1999
# cyl                      4
# trans             auto(l4)
# drv                      f
# cty                     29
# hwy                     41
# fl                       d
# category        subcompact
# Name: 222, dtype: object

# %%
mpg.loc[[1,10,100]]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 10          audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# 100        honda       civic    1.6  1999    4    auto(l4)   f   24   32  r
#
#        category
# 1       compact
# 10      compact
# 100  subcompact

# %% [markdown]
# ### iloc?

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
## 행 번호 기준
mpg.iloc[1]
# Out:
# manufacturer          audi
# model                   a4
# displ                  1.8
# year                  1999
# cyl                      4
# trans           manual(m5)
# drv                      f
# cty                     21
# hwy                     29
# fl                       p
# category           compact
# Name: 1, dtype: object

# %%
mpg.loc[1]
# Out:
# manufacturer          audi
# model                   a4
# displ                  1.8
# year                  1999
# cyl                      4
# trans           manual(m5)
# drv                      f
# cty                     21
# hwy                     29
# fl                       p
# category           compact
# Name: 1, dtype: object

# %%
df = mpg.loc[[1,10,100]]

# %%
df.loc[10]
# Out:
# manufacturer          audi
# model           a4 quattro
# displ                    2
# year                  2008
# cyl                      4
# trans             auto(s6)
# drv                      4
# cty                     19
# hwy                     27
# fl                       p
# category           compact
# Name: 10, dtype: object

# %%
df.iloc[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-3def72b16967> in <module>
# ----> 1 df.iloc[10]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2135
#    2136             # validate the location
# -> 2137             self._validate_integer(key, axis)
#    2138
#    2139             return self._get_loc(key, axis=axis)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
# ...

# %%
df.iloc[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-dd7c84f36f80> in <module>
# ----> 1 df.iloc[3]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2135
#    2136             # validate the location
# -> 2137             self._validate_integer(key, axis)
#    2138
#    2139             return self._get_loc(key, axis=axis)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2060         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
df.iloc[2]
# Out:
# manufacturer         honda
# model                civic
# displ                  1.6
# year                  1999
# cyl                      4
# trans             auto(l4)
# drv                      f
# cty                     24
# hwy                     32
# fl                       r
# category        subcompact
# Name: 100, dtype: object

# %%
df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 10          audi  a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# 100        honda       civic    1.6  1999    4    auto(l4)   f   24   32  r
#
#        category
# 1       compact
# 10      compact
# 100  subcompact

# %%
df.loc[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-1f40c40b27b2> in <module>
# ----> 1 df.loc[2]
#
# ...

# %% [markdown]
# ### 데이터 추출시 슬라이싱이 가능하다

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'category'],
#       dtype='object')

# %%
df_new=mpg.loc[:, ['model','year']]

# %%
mpg.loc[:, [1,2,3]] #컬럼을 가지고 올 때 문자로만 컬럼을 정확하게 설명해 한다.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-cd8dcfbf8f85> in <module>
# ----> 1 mpg.loc[:, [1,2,3]]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1286                 continue
#    1287
# -> 1288             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1289
#    1290         return retval
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
mpg.iloc[50:55, [1,2,3]] #컬럼을 가지고 올 때 문자로만 컬럼을 정확하게 설명해 한다.
# Out:
#                 model  displ  year
# 50  dakota pickup 4wd    3.9  1999
# 51  dakota pickup 4wd    3.9  1999
# 52  dakota pickup 4wd    4.7  2008
# 53  dakota pickup 4wd    4.7  2008
# 54  dakota pickup 4wd    4.7  2008

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
sm_r = list(range(4))

# %%
sm_r
# Out:
# [0, 1, 2, 3]

# %%
mpg.iloc[:,sm_r]
# Out:
#     manufacturer   model  displ  year
# 0           audi      a4    1.8  1999
# 1           audi      a4    1.8  1999
# 2           audi      a4    2.0  2008
# 3           audi      a4    2.0  2008
# 4           audi      a4    2.8  1999
# ..           ...     ...    ...   ...
# 229   volkswagen  passat    2.0  2008
# 230   volkswagen  passat    2.0  2008
# 231   volkswagen  passat    2.8  1999
# 232   volkswagen  passat    2.8  1999
# 233   volkswagen  passat    3.6  2008
#
# [234 rows x 4 columns]

# %%
mpg.iloc[:,:3]
# Out:
#     manufacturer   model  displ
# 0           audi      a4    1.8
# 1           audi      a4    1.8
# 2           audi      a4    2.0
# 3           audi      a4    2.0
# 4           audi      a4    2.8
# ..           ...     ...    ...
# 229   volkswagen  passat    2.0
# 230   volkswagen  passat    2.0
# 231   volkswagen  passat    2.8
# 232   volkswagen  passat    2.8
# 233   volkswagen  passat    3.6
#
# [234 rows x 3 columns]

# %% [markdown]
# ### 필수과제
#
# - mpg, gaminder 데이터를 가지고
# - loc, iloc 코드를 짜주세요! 최소 10개 이상
# - 슬라이싱, 변수화 등 다양하게 진행해 주시고 주석처리 필수!

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.groupby('year')['pop'].mean()
# Out:
# year
# 1952    1.695040e+07
# 1957    1.876341e+07
# 1962    2.042101e+07
# 1967    2.265830e+07
# 1972    2.518998e+07
# 1977    2.767638e+07
# 1982    3.020730e+07
# 1987    3.303857e+07
# 1992    3.599092e+07
# 1997    3.883947e+07
# 2002    4.145759e+07
# 2007    4.402122e+07
# Name: pop, dtype: float64

# %%
df_gr = df.groupby(['year','lifeExp'])[['pop','gdpPercap']].mean()

# %%
df.groupby(['lifeExp','year'])[['pop','gdpPercap']].mean()
# Out:
#                       pop     gdpPercap
# lifeExp year
# 23.599  1992    7290203.0    737.068595
# 28.801  1952    8425333.0    779.445314
# 30.000  1952     284320.0    485.230659
# 30.015  1952    4232095.0   3520.610273
# 30.331  1952    2143249.0    879.787736
# ...                   ...           ...
# 81.701  2007    7554661.0  37506.419070
# 81.757  2007     301931.0  36180.789190
# 82.000  2002  127065841.0  28604.591900
# 82.208  2007    6980412.0  39724.978670
# 82.603  2007  127467972.0  31656.068060
#
# [1700 rows x 2 columns]

# %%
df_gr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1700 entries, (1952, 28.801) to (2007, 82.603)
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pop        1700 non-null   float64
#  1   gdpPercap  1700 non-null   float64
# dtypes: float64(2)
# memory usage: 44.5 KB

# %%
df_gr
# Out:
#                       pop     gdpPercap
# year lifeExp
# 1952 28.801     8425333.0    779.445314
#      30.000      284320.0    485.230659
#      30.015     4232095.0   3520.610273
#      30.331     2143249.0    879.787736
#      31.286     6446316.0    468.526038
# ...                   ...           ...
# 2007 81.235    20434176.0  34435.367440
#      81.701     7554661.0  37506.419070
#      81.757      301931.0  36180.789190
#      82.208     6980412.0  39724.978670
#      82.603   127467972.0  31656.068060
#
# [1700 rows x 2 columns]

# %% [markdown]
# ### 간단하게 시각화 진행해 보기!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
# 쥬피터 노트북에서 그래프를 그리기 위해서 사용

# %%
df_exp=df.groupby('year')['lifeExp'].mean()

# %%
df_exp.plot()

# %%
df_exp
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %% [markdown]
# ### 시각화는 본인의 분석 목적에 맞게 그래프를 그려야 한다!

# %% [markdown]
# ### 판다스 데이터프레임과 시리즈

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg['model']
# Out:
# 0          a4
# 1          a4
# 2          a4
# 3          a4
# 4          a4
#         ...
# 229    passat
# 230    passat
# 231    passat
# 232    passat
# 233    passat
# Name: model, Length: 234, dtype: object

# %% [markdown]
# #### 시리즈형태가 판다스에서 연산할 때 아주 유용하고, 엑셀의 개념

# %%
#시리즈 만들어 보기!

a = pd.Series(['안녕','안녕하세요'])

# %%
a
# Out:
# 0       안녕
# 1    안녕하세요
# dtype: object

# %%
#데이터 프레임 만들기! # 2차원 행과 열을 지정해 줘야 한다!
abc = pd.DataFrame({
    'Name':['홍길동','임꺽정','김영희'],
    '나이':[11,12,13]
})

# %%
abc
# Out:
#   Name  나이
# 0  홍길동  11
# 1  임꺽정  12
# 2  김영희  13

# %%
abc.iloc[2]
# Out:
# Name    김영희
# 나이       13
# Name: 2, dtype: object

# %%
abc.loc[3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     349             try:
# --> 350                 return self._range.index(new_key)
#     351             except ValueError:
#
# ValueError: 3 is not in range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-01beb8fdcd1f> in <module>
# ----> 1 abc.loc[3]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ...

# %%
#데이터 프레임 만들기! # 2차원 행과 열을 지정해 줘야 한다!
abc = pd.DataFrame({
    'Name':['홍길동','임꺽정','김영희'],
    '나이':[11,12,13]
},
index = ['1반','2반','3반'])

# %%
abc
# Out:
#    Name  나이
# 1반  홍길동  11
# 2반  임꺽정  12
# 3반  김영희  13

# %%
abc
# Out:
#   Name  나이
# 0  홍길동  11
# 1  임꺽정  12
# 2  김영희  13
